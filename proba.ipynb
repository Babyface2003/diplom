# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\ivanr\PycharmProjects\VKR\4_курс\split_file_2.xlsx", header=None)
df.columns = df.iloc[1]
df = df.iloc[2:]
df
# Out:
# 1   NaN    ИДБ-21-11        NaN    09.03.03-02  NaN NaN   ИДБ-21-12  \
# 2     1        Алиев       Муса      Ясиф оглы  NaN   1     Бизюков
# 3     2  Барышникова      Дарья  Александровна  NaN   2    Вишняков
# 4     3   Вишневский     Феликс  Александрович  NaN   3  Воложенина
# 5     4      Дебелов       Егор      Андреевич  NaN   4    Гребенюк
# 6     5       Кабаев     Виктор     Алексеевич  NaN   5       Греку
# 7     6    Карапетян      Карен      Рутикович  NaN   6      Жданов
# 8     7     Макарова  Маргарита  Александровна  NaN   7    Журавлев
# 9     8       Табуев     Платон     Ролантович  NaN   8   Журавлева
# 10    9      Шевяков     Виктор      Сергеевич  NaN   9    Захарова
# 11   10       Шундев     Кирилл     Михайлович  NaN  10     Клинова
# 12  NaN          NaN        NaN            NaN  NaN  11   Кудряшова
# 13  NaN          NaN        NaN            NaN  NaN  12     Куликов
# 14  NaN          NaN        NaN            NaN  NaN  13       Малов
# ...
